# %% [markdown]
# # Basics stuff

# %% [markdown]
# Create a list of random numbers 0-1 using random() and plot it

# %%
# %matplotlib notebook
# This lets jupyter plot in-line
#Can also use: %matplotlib inline
import matplotlib.pyplot as plt
import random
import numpy as np

fig1 = plt.figure(1)
#Create Random List
rand_list = [random.random() for _ in range(20)]
_ = plt.hist(rand_list)
plt.show()
#If I don't use _ = then the array returns in-line
 
#Mean
avg = np.mean(rand_list)
print("Mean:\t%.4f\t(average)" %avg)
#Median
print("Median:\t%.4f\t(datapoint nearest middle)" %np.median(rand_list))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Mean:	0.5224	(average)
# Median:	0.4971	(datapoint nearest middle)

# %% [markdown]
# What are the standard deviation, variance? And what do they have to do with a normal distribution?

# %%
#STD
std = np.std(rand_list)
print("Sigma:\t%.4f\t(standard deviation)" %std)
#Variance
var = np.var(rand_list)
print("Var:\t%.4f\t(Variance)" %var)
print("Var=std**2?:  %s" %(var == std**2))
print("Normal distribution and standard deviations:")
from IPython.display import Image
Image("Std_dev.jpg",width=350,height=350)
#PDF
#CDF
# Out:
# Sigma:	0.3201	(standard deviation)
# Var:	0.1025	(Variance)
# Var=std**2?:  True
# Normal distribution and standard deviations:

# %%
#Now let's overlay our histogram plot with a normal distribution
plt.close(fig1)
fig2 = plt.figure(2)
ax1=fig2.add_subplot(111)
_ = plt.hist(rand_list)
#setup normal distribution
from scipy.stats import norm
x = np.linspace(avg-3*std, avg+3*std,100)
ax2 = fig2.add_subplot(111, sharex=ax1, frameon=False)
ax2.yaxis.tick_right()
plt.plot(x, norm.pdf(x,avg,std),'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''
PDF and CDF
PDF = Probability distribution function
A distribution that shows the probability at any X value
CDF = Cumulative distribution function
Distribution shows the probability summed up to that X value
'''
plt.close(fig2)
dx=0.01
x = np.arange(-2,2,dx)
y = np.exp(-x**2)
# normalize to 1
y /= (y*dx).sum()
cdfy = np.cumsum(y*dx)
fig3 = plt.figure(3)
plt.plot(x,y,'r',label="PDF")
plt.plot(x,cdfy,'k--',label="CDF")
_=plt.legend(loc=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## T Test and Z test:
#
# ### Z distribution
# Z distribution is the normal distribution.
# Use when sigma is known AND samples > 30
#
# ### T distribution
# T is a wider distribution than the Z distribution (both integrate to 1)
# Use when you may not know the sigma and n < 30
#
# <b>What that looks like:</b>

# %%
Image("t-vs-z_orig.png",width=400,height=400)

# %%
print("Rough rules for choosing")
Image("t-score-vs.-z-score.png",width=350,height=350)
# Out:
# Rough rules for choosing

# %% [markdown]
# ## Z-test of two means:
# Know the two means and stds
# Test overlays them, finds if the mean is within alpha/2 (for two sided)
# Beta is the chance that we say the medians are equal when they actually arent

# %%
Image("Rejection Region2.png", width=350,height=350)
